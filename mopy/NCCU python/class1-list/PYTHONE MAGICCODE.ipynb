# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-1,-6,-9])

# %%
randn(10)
# Out:
# array([-0.22626987,  0.11157468, -0.5252524 ,  1.23103443, -0.84959594,
#        -0.38436394,  0.6022676 , -0.06545346,  1.6881971 , -1.25774243])

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[23,-5,6,0])
